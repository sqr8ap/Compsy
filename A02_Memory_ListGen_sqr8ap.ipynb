# %% [markdown]
# ## Assignment02: Memory List Generation
# ### Sam Remmey, sqr8ap
# #### Collaborated with Sara Grace Kennedy, sgk9hr

# %% [markdown]
# #### Imports & reading in csv files

# %%
import random
import csv
from copy import deepcopy
import os

# %%
# setting directory to where I put the csv files

os.chdir('/Users/Samantha/Desktop/PSYC4215')

# %%
dr = csv.DictReader(open('pos_pool.csv','r'))

# %%
pos_pool = [l for l in dr]
random.shuffle(pos_pool)

# %%
dr2 = csv.DictReader(open('neg_pool.csv','r'))

# %%
neg_pool = [l for l in dr2]
random.shuffle(neg_pool)

# %%
dr3 = csv.DictReader(open('neu_pool.csv','r'))

# %%
neu_pool = [l for l in dr3]
random.shuffle(neu_pool)

# %% [markdown]
# #### Creating conditions & initializing variables

# %%
conditions = [{'valence':'pos','cond':'repeat'},
              {'valence':'pos','cond':'refresh'},
              {'valence':'pos','cond':'once'},
              {'valence':'neg','cond':'repeat'},
              {'valence':'neg','cond':'refresh'},
              {'valence':'neg','cond':'once'},
              {'valence':'neu','cond':'repeat'},
              {'valence':'neu','cond':'refresh'},
              {'valence':'neu','cond':'once'}]

random.shuffle(conditions)

num_reps = 2
num_blocks = 2

# %% [markdown]
# #### Making the study and test lists

# %%
def make_trials(num_reps, conditions):
    """
    This function takes two inputs: the number of repetitions needed in a given list (num_reps), and a list of 
    experimental conditions (conditions). It returns a dictionary that contains a study list and corresponding test list. 
    The study list contains a list of words that are repeated as specified by the conditions. The test list contains 
    these same words presented one time each as well as corresponding lures of the same valence (1:1 ratio of target words 
    to test words). 
    """
    
    # declaring global variables so we can access the data within the function
    global pos_pool
    global neg_pool
    global neu_pool
    
    # shuffle conditions within the function but before the loop so that the conditions are shuffled for each block
    random.shuffle(conditions)
    
    # initializing local variables for study and test lists; the function will return these in a dictionary
    study_list = []
    test_list = []
    
    for i in range(num_reps): 
        for condition in conditions:
            # choosing pool to draw from based on valence needed
            valence = condition['valence']
            if valence == 'pos':
                pool = pos_pool
            elif valence == 'neg':
                pool = neg_pool
            elif valence == 'neu':
                pool = neu_pool

            # looping through conditions and appending study list and test list with words
            if condition['cond'] == 'once':
                target_item = pool.pop()
                target_item['valence'] = condition['valence']
                target_item['pres_num'] = 1
                target_item['probe'] = 'target'
                target_item['cond'] = 'once'

                lure_item = pool.pop()
                lure_item['valence'] = condition['valence']
                lure_item['pres_num'] = 1
                lure_item['probe'] = 'lure'
                lure_item['cond'] = 'once'

                study_list.append(target_item)
                test_list.append(target_item)
                test_list.append(lure_item)
            elif condition['cond'] == 'repeat':
                target_item = pool.pop()
                target_item['valence'] = condition['valence']
                target_item['pres_num'] = 1
                target_item['probe'] = 'target'
                target_item['cond'] = 'repeat'

                next_item = deepcopy(target_item)
                next_item['pres_num'] = 2

                lure_item = pool.pop()
                lure_item['valence'] = condition['valence']
                lure_item['pres_num'] = 1
                lure_item['probe'] = 'lure'
                lure_item['cond'] = 'repeat'

                study_list.append(target_item)
                study_list.append(next_item)
                test_list.append(target_item)
                test_list.append(lure_item)
            elif condition['cond'] == 'refresh':
                target_item = pool.pop()
                target_item['valence'] = condition['valence']
                target_item['pres_num'] = 1
                target_item['probe'] = 'target'
                target_item['cond'] = 'refresh'

                next_item = deepcopy(target_item)
                next_item['description'] = '+'
                next_item['pres_num'] = 2

                lure_item = pool.pop()
                lure_item['valence'] = condition['valence']
                lure_item['pres_num'] = 1
                lure_item['probe'] = 'lure'
                lure_item['cond'] = 'refresh'

                study_list.append(target_item)
                study_list.append(next_item)
                test_list.append(target_item)
                test_list.append(lure_item)

    random.shuffle(test_list)
        
    trial_dict = {'study': study_list, 'test': test_list}
    return trial_dict

# %% [markdown]
# #### Creating blocks

# %%
experiment_blocks = [make_trials(num_reps, conditions) for i in range(num_blocks)]

# %% [markdown]
# #### Printing a block

# %%
# printing one block to show functionality; I have num_reps set equal to 2, so the study list has 30 items, and
# the test list has 36 

print(len(experiment_blocks))
experiment_blocks[0]
# Out:
# 2
# {'study': [{'description': 'arrogant',
#    'word_no': '25',
#    'valence_mean': '3.6899999999999999',
#    'valence_sd': '2.3999999999999999',
#    'arousal_mean': '5.6500000000000004',
#    'arousal_sd': '2.23',
#    'dominance_mean': '5.1399999999999997',
#    'dominance_sd': '2.71',
#    'word_frequency': '2',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': '+',
#    'word_no': '25',
#    'valence_mean': '3.6899999999999999',
#    'valence_sd': '2.3999999999999999',
#    'arousal_mean': '5.6500000000000004',
#    'arousal_sd': '2.23',
#    'dominance_mean': '5.1399999999999997',
#    'dominance_sd': '2.71',
#    'word_frequency': '2',
#    'valence': 'neg',
#    'pres_num': 2,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': 'farm',
#    'word_no': '557',
#    'valence_mean': '5.5300000000000002',
#    'valence_sd': '1.8500000000000001',
#    'arousal_mean': '3.8999999999999999',
#    'arousal_sd': '1.95',
#    'dominance_mean': '5.5899999999999999',
#    'dominance_sd': '1.8100000000000001',
#    'word_frequency': '125',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'once'},
#   {'description': 'hotel',
#    'word_no': '795',
#    'valence_mean': '6.0',
#    'valence_sd': '1.77',
#    'arousal_mean': '4.7999999999999998',
#    'arousal_sd': '2.5299999999999998',
#    'dominance_mean': '5.1200000000000001',
#    'dominance_sd': '1.8400000000000001',
#    'word_frequency': '126',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': '+',
#    'word_no': '795',
#    'valence_mean': '6.0',
#    'valence_sd': '1.77',
#    'arousal_mean': '4.7999999999999998',
#    'arousal_sd': '2.5299999999999998',
#    'dominance_mean': '5.1200000000000001',
#    'dominance_sd': '1.8400000000000001',
#    'word_frequency': '126',
#    'valence': 'neu',
#    'pres_num': 2,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': 'contents',
#    'word_no': '83',
#    'valence_mean': '4.8899999999999997',
#    'valence_sd': '0.89000000000000001',
#    'arousal_mean': '4.3200000000000003',
#    'arousal_sd': '2.1400000000000001',
#    'dominance_mean': '4.8499999999999996',
#    'dominance_sd': '1.49',
#    'word_frequency': '16',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'contents',
#    'word_no': '83',
#    'valence_mean': '4.8899999999999997',
#    'valence_sd': '0.89000000000000001',
#    'arousal_mean': '4.3200000000000003',
#    'arousal_sd': '2.1400000000000001',
#    'dominance_mean': '4.8499999999999996',
#    'dominance_sd': '1.49',
#    'word_frequency': '16',
#    'valence': 'neu',
#    'pres_num': 2,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'lucky',
#    'word_no': '266',
#    'valence_mean': '8.1699999999999999',
#    'valence_sd': '1.0600000000000001',
#    'arousal_mean': '6.5300000000000002',
#    'arousal_sd': '2.3399999999999999',
#    'dominance_mean': '6.0499999999999998',
#    'dominance_sd': '2.25',
#    'word_frequency': '21',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': '+',
#    'word_no': '266',
#    'valence_mean': '8.1699999999999999',
#    'valence_sd': '1.0600000000000001',
#    'arousal_mean': '6.5300000000000002',
#    'arousal_sd': '2.3399999999999999',
#    'dominance_mean': '6.0499999999999998',
#    'dominance_sd': '2.25',
#    'word_frequency': '21',
#    'valence': 'pos',
#    'pres_num': 2,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': 'loneliness',
#    'word_no': '260',
#    'valence_mean': '1.6100000000000001',
#    'valence_sd': '1.02',
#    'arousal_mean': '4.5599999999999996',
#    'arousal_sd': '2.9700000000000002',
#    'dominance_mean': '2.5099999999999998',
#    'dominance_sd': '2.27',
#    'word_frequency': '9',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'loneliness',
#    'word_no': '260',
#    'valence_mean': '1.6100000000000001',
#    'valence_sd': '1.02',
#    'arousal_mean': '4.5599999999999996',
#    'arousal_sd': '2.9700000000000002',
#    'dominance_mean': '2.5099999999999998',
#    'dominance_sd': '2.27',
#    'word_frequency': '9',
#    'valence': 'neg',
#    'pres_num': 2,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'kids',
#    'word_no': '835',
#    'valence_mean': '6.9100000000000001',
#    'valence_sd': '1.99',
#    'arousal_mean': '5.2699999999999996',
#    'arousal_sd': '2.3599999999999999',
#    'dominance_mean': '5.0700000000000003',
#    'dominance_sd': '2.0299999999999998',
#    'word_frequency': '32',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'kids',
#    'word_no': '835',
#    'valence_mean': '6.9100000000000001',
#    'valence_sd': '1.99',
#    'arousal_mean': '5.2699999999999996',
#    'arousal_sd': '2.3599999999999999',
#    'dominance_mean': '5.0700000000000003',
#    'dominance_sd': '2.0299999999999998',
#    'word_frequency': '32',
#    'valence': 'pos',
#    'pres_num': 2,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'silk',
#    'word_no': '391',
#    'valence_mean': '6.9000000000000004',
#    'valence_sd': '1.27',
#    'arousal_mean': '3.71',
#    'arousal_sd': '2.5099999999999998',
#    'dominance_mean': '4.8099999999999996',
#    'dominance_sd': '1.9299999999999999',
#    'word_frequency': '12',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'once'},
#   {'description': 'scandal',
#    'word_no': '971',
#    'valence_mean': '3.3199999999999998',
#    'valence_sd': '1.8100000000000001',
#    'arousal_mean': '5.1200000000000001',
#    'arousal_sd': '2.2200000000000002',
#    'dominance_mean': '4.3399999999999999',
#    'dominance_sd': '1.73',
#    'word_frequency': '8',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'once'},
#   {'description': 'hungry',
#    'word_no': '221',
#    'valence_mean': '3.5800000000000001',
#    'valence_sd': '2.0099999999999998',
#    'arousal_mean': '5.1299999999999999',
#    'arousal_sd': '2.4399999999999999',
#    'dominance_mean': '4.6799999999999997',
#    'dominance_sd': '2.0499999999999998',
#    'word_frequency': '23',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': '+',
#    'word_no': '221',
#    'valence_mean': '3.5800000000000001',
#    'valence_sd': '2.0099999999999998',
#    'arousal_mean': '5.1299999999999999',
#    'arousal_sd': '2.4399999999999999',
#    'dominance_mean': '4.6799999999999997',
#    'dominance_sd': '2.0499999999999998',
#    'word_frequency': '23',
#    'valence': 'neg',
#    'pres_num': 2,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': 'pamphlet',
#    'word_no': '925',
#    'valence_mean': '4.79',
#    'valence_sd': '1.05',
#    'arousal_mean': '3.6200000000000001',
#    'arousal_sd': '2.02',
#    'dominance_mean': '4.6299999999999999',
#    'dominance_sd': '1.48',
#    'word_frequency': '3',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'once'},
#   {'description': 'chance',
#    'word_no': '683',
#    'valence_mean': '6.0199999999999996',
#    'valence_sd': '1.77',
#    'arousal_mean': '5.3799999999999999',
#    'arousal_sd': '2.5800000000000001',
#    'dominance_mean': '4.6399999999999997',
#    'dominance_sd': '1.9299999999999999',
#    'word_frequency': '131',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': '+',
#    'word_no': '683',
#    'valence_mean': '6.0199999999999996',
#    'valence_sd': '1.77',
#    'arousal_mean': '5.3799999999999999',
#    'arousal_sd': '2.5800000000000001',
#    'dominance_mean': '4.6399999999999997',
#    'dominance_sd': '1.9299999999999999',
#    'word_frequency': '131',
#    'valence': 'neu',
#    'pres_num': 2,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': 'egg',
#    'word_no': '736',
#    'valence_mean': '5.29',
#    'valence_sd': '1.8200000000000001',
#    'arousal_mean': '3.7599999999999998',
#    'arousal_sd': '2.3900000000000001',
#    'dominance_mean': '4.4900000000000002',
#    'dominance_sd': '2.1600000000000001',
#    'word_frequency': '12',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'egg',
#    'word_no': '736',
#    'valence_mean': '5.29',
#    'valence_sd': '1.8200000000000001',
#    'arousal_mean': '3.7599999999999998',
#    'arousal_sd': '2.3900000000000001',
#    'dominance_mean': '4.4900000000000002',
#    'dominance_sd': '2.1600000000000001',
#    'word_frequency': '12',
#    'valence': 'neu',
#    'pres_num': 2,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'inspired',
#    'word_no': '233',
#    'valence_mean': '7.1500000000000004',
#    'valence_sd': '1.8500000000000001',
#    'arousal_mean': '6.0199999999999996',
#    'arousal_sd': '2.6699999999999999',
#    'dominance_mean': '6.6699999999999999',
#    'dominance_sd': '2.3100000000000001',
#    'word_frequency': '25',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': '+',
#    'word_no': '233',
#    'valence_mean': '7.1500000000000004',
#    'valence_sd': '1.8500000000000001',
#    'arousal_mean': '6.0199999999999996',
#    'arousal_sd': '2.6699999999999999',
#    'dominance_mean': '6.6699999999999999',
#    'dominance_sd': '2.3100000000000001',
#    'word_frequency': '25',
#    'valence': 'pos',
#    'pres_num': 2,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': 'leprosy',
#    'word_no': '254',
#    'valence_mean': '2.0899999999999999',
#    'valence_sd': '1.3999999999999999',
#    'arousal_mean': '6.29',
#    'arousal_sd': '2.23',
#    'dominance_mean': '4.0',
#    'dominance_sd': '2.2999999999999998',
#    'word_frequency': '1',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'leprosy',
#    'word_no': '254',
#    'valence_mean': '2.0899999999999999',
#    'valence_sd': '1.3999999999999999',
#    'arousal_mean': '6.29',
#    'arousal_sd': '2.23',
#    'dominance_mean': '4.0',
#    'dominance_sd': '2.2999999999999998',
#    'word_frequency': '1',
#    'valence': 'neg',
#    'pres_num': 2,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'ambition',
#    'word_no': '14',
#    'valence_mean': '7.04',
#    'valence_sd': '1.98',
#    'arousal_mean': '5.6100000000000003',
#    'arousal_sd': '2.9199999999999999',
#    'dominance_mean': '6.9299999999999997',
#    'dominance_sd': '2.0699999999999998',
#    'word_frequency': '19',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'ambition',
#    'word_no': '14',
#    'valence_mean': '7.04',
#    'valence_sd': '1.98',
#    'arousal_mean': '5.6100000000000003',
#    'arousal_sd': '2.9199999999999999',
#    'dominance_mean': '6.9299999999999997',
#    'dominance_sd': '2.0699999999999998',
#    'word_frequency': '19',
#    'valence': 'pos',
#    'pres_num': 2,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'astonished',
#    'word_no': '28',
#    'valence_mean': '6.5599999999999996',
#    'valence_sd': '1.6100000000000001',
#    'arousal_mean': '6.5800000000000001',
#    'arousal_sd': '2.2200000000000002',
#    'dominance_mean': '5.1600000000000001',
#    'dominance_sd': '1.79',
#    'word_frequency': '6',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'once'},
#   {'description': 'infection',
#    'word_no': '228',
#    'valence_mean': '1.6599999999999999',
#    'valence_sd': '1.3400000000000001',
#    'arousal_mean': '5.0300000000000002',
#    'arousal_sd': '2.77',
#    'dominance_mean': '3.6099999999999999',
#    'dominance_sd': '2.6400000000000001',
#    'word_frequency': '8',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'once'}],
#  'test': [{'description': 'chance',
#    'word_no': '683',
#    'valence_mean': '6.0199999999999996',
#    'valence_sd': '1.77',
#    'arousal_mean': '5.3799999999999999',
#    'arousal_sd': '2.5800000000000001',
#    'dominance_mean': '4.6399999999999997',
#    'dominance_sd': '1.9299999999999999',
#    'word_frequency': '131',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': 'hairdryer',
#    'word_no': '561',
#    'valence_mean': '4.8399999999999999',
#    'valence_sd': '0.83999999999999997',
#    'arousal_mean': '3.71',
#    'arousal_sd': '1.75',
#    'dominance_mean': '5.5700000000000003',
#    'dominance_sd': '1.27',
#    'word_frequency': '.',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'once'},
#   {'description': 'city',
#    'word_no': '73',
#    'valence_mean': '6.0300000000000002',
#    'valence_sd': '1.3700000000000001',
#    'arousal_mean': '5.2400000000000002',
#    'arousal_sd': '2.5299999999999998',
#    'dominance_mean': '5.7400000000000002',
#    'dominance_sd': '2.0800000000000001',
#    'word_frequency': '393',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'once'},
#   {'description': 'ambition',
#    'word_no': '14',
#    'valence_mean': '7.04',
#    'valence_sd': '1.98',
#    'arousal_mean': '5.6100000000000003',
#    'arousal_sd': '2.9199999999999999',
#    'dominance_mean': '6.9299999999999997',
#    'dominance_sd': '2.0699999999999998',
#    'word_frequency': '19',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'pamphlet',
#    'word_no': '925',
#    'valence_mean': '4.79',
#    'valence_sd': '1.05',
#    'arousal_mean': '3.6200000000000001',
#    'arousal_sd': '2.02',
#    'dominance_mean': '4.6299999999999999',
#    'dominance_sd': '1.48',
#    'word_frequency': '3',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'once'},
#   {'description': 'easygoing',
#    'word_no': '135',
#    'valence_mean': '7.2000000000000002',
#    'valence_sd': '1.5',
#    'arousal_mean': '4.2999999999999998',
#    'arousal_sd': '2.52',
#    'dominance_mean': '5.25',
#    'dominance_sd': '1.75',
#    'word_frequency': '1',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'once'},
#   {'description': 'scandal',
#    'word_no': '971',
#    'valence_mean': '3.3199999999999998',
#    'valence_sd': '1.8100000000000001',
#    'arousal_mean': '5.1200000000000001',
#    'arousal_sd': '2.2200000000000002',
#    'dominance_mean': '4.3399999999999999',
#    'dominance_sd': '1.73',
#    'word_frequency': '8',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'once'},
#   {'description': 'hungry',
#    'word_no': '221',
#    'valence_mean': '3.5800000000000001',
#    'valence_sd': '2.0099999999999998',
#    'arousal_mean': '5.1299999999999999',
#    'arousal_sd': '2.4399999999999999',
#    'dominance_mean': '4.6799999999999997',
#    'dominance_sd': '2.0499999999999998',
#    'word_frequency': '23',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': 'arrogant',
#    'word_no': '25',
#    'valence_mean': '3.6899999999999999',
#    'valence_sd': '2.3999999999999999',
#    'arousal_mean': '5.6500000000000004',
#    'arousal_sd': '2.23',
#    'dominance_mean': '5.1399999999999997',
#    'dominance_sd': '2.71',
#    'word_frequency': '2',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': 'fungus',
#    'word_no': '179',
#    'valence_mean': '3.0600000000000001',
#    'valence_sd': '1.75',
#    'arousal_mean': '4.6799999999999997',
#    'arousal_sd': '2.3300000000000001',
#    'dominance_mean': '4.0599999999999996',
#    'dominance_sd': '1.9399999999999999',
#    'word_frequency': '2',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'once'},
#   {'description': 'farm',
#    'word_no': '557',
#    'valence_mean': '5.5300000000000002',
#    'valence_sd': '1.8500000000000001',
#    'arousal_mean': '3.8999999999999999',
#    'arousal_sd': '1.95',
#    'dominance_mean': '5.5899999999999999',
#    'dominance_sd': '1.8100000000000001',
#    'word_frequency': '125',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'once'},
#   {'description': 'stupid',
#    'word_no': '415',
#    'valence_mean': '2.3100000000000001',
#    'valence_sd': '1.3700000000000001',
#    'arousal_mean': '4.7199999999999998',
#    'arousal_sd': '2.71',
#    'dominance_mean': '2.98',
#    'dominance_sd': '2.1800000000000002',
#    'word_frequency': '24',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'once'},
#   {'description': 'cuisine',
#    'word_no': '709',
#    'valence_mean': '6.6399999999999997',
#    'valence_sd': '1.48',
#    'arousal_mean': '4.3899999999999997',
#    'arousal_sd': '1.99',
#    'dominance_mean': '5.4100000000000001',
#    'dominance_sd': '1.1899999999999999',
#    'word_frequency': '1',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'repeat'},
#   {'description': 'astonished',
#    'word_no': '28',
#    'valence_mean': '6.5599999999999996',
#    'valence_sd': '1.6100000000000001',
#    'arousal_mean': '6.5800000000000001',
#    'arousal_sd': '2.2200000000000002',
#    'dominance_mean': '5.1600000000000001',
#    'dominance_sd': '1.79',
#    'word_frequency': '6',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'once'},
#   {'description': 'gold',
#    'word_no': '191',
#    'valence_mean': '7.54',
#    'valence_sd': '1.6299999999999999',
#    'arousal_mean': '5.7599999999999998',
#    'arousal_sd': '2.79',
#    'dominance_mean': '5.8499999999999996',
#    'dominance_sd': '2.46',
#    'word_frequency': '52',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'refresh'},
#   {'description': 'clock',
#    'word_no': '688',
#    'valence_mean': '5.1399999999999997',
#    'valence_sd': '1.54',
#    'arousal_mean': '4.0199999999999996',
#    'arousal_sd': '2.54',
#    'dominance_mean': '4.6699999999999999',
#    'dominance_sd': '1.97',
#    'word_frequency': '20',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'refresh'},
#   {'description': 'outdoors',
#    'word_no': '521',
#    'valence_mean': '7.4699999999999998',
#    'valence_sd': '1.8',
#    'arousal_mean': '5.9199999999999999',
#    'arousal_sd': '2.5499999999999998',
#    'dominance_mean': '6.2699999999999996',
#    'dominance_sd': '2.2400000000000002',
#    'word_frequency': '6',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'once'},
#   {'description': 'feeble',
#    'word_no': '164',
#    'valence_mean': '3.2599999999999998',
#    'valence_sd': '1.47',
#    'arousal_mean': '4.0999999999999996',
#    'arousal_sd': '2.0699999999999998',
#    'dominance_mean': '2.71',
#    'dominance_sd': '1.6399999999999999',
#    'word_frequency': '8',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'refresh'},
#   {'description': 'loneliness',
#    'word_no': '260',
#    'valence_mean': '1.6100000000000001',
#    'valence_sd': '1.02',
#    'arousal_mean': '4.5599999999999996',
#    'arousal_sd': '2.9700000000000002',
#    'dominance_mean': '2.5099999999999998',
#    'dominance_sd': '2.27',
#    'word_frequency': '9',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'color',
#    'word_no': '694',
#    'valence_mean': '7.0199999999999996',
#    'valence_sd': '1.5700000000000001',
#    'arousal_mean': '4.7300000000000004',
#    'arousal_sd': '2.6400000000000001',
#    'dominance_mean': '6.1699999999999999',
#    'dominance_sd': '1.8200000000000001',
#    'word_frequency': '141',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'repeat'},
#   {'description': 'egg',
#    'word_no': '736',
#    'valence_mean': '5.29',
#    'valence_sd': '1.8200000000000001',
#    'arousal_mean': '3.7599999999999998',
#    'arousal_sd': '2.3900000000000001',
#    'dominance_mean': '4.4900000000000002',
#    'dominance_sd': '2.1600000000000001',
#    'word_frequency': '12',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'lucky',
#    'word_no': '266',
#    'valence_mean': '8.1699999999999999',
#    'valence_sd': '1.0600000000000001',
#    'arousal_mean': '6.5300000000000002',
#    'arousal_sd': '2.3399999999999999',
#    'dominance_mean': '6.0499999999999998',
#    'dominance_sd': '2.25',
#    'word_frequency': '21',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': 'inspired',
#    'word_no': '233',
#    'valence_mean': '7.1500000000000004',
#    'valence_sd': '1.8500000000000001',
#    'arousal_mean': '6.0199999999999996',
#    'arousal_sd': '2.6699999999999999',
#    'dominance_mean': '6.6699999999999999',
#    'dominance_sd': '2.3100000000000001',
#    'word_frequency': '25',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': 'contents',
#    'word_no': '83',
#    'valence_mean': '4.8899999999999997',
#    'valence_sd': '0.89000000000000001',
#    'arousal_mean': '4.3200000000000003',
#    'arousal_sd': '2.1400000000000001',
#    'dominance_mean': '4.8499999999999996',
#    'dominance_sd': '1.49',
#    'word_frequency': '16',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'despairing',
#    'word_no': '110',
#    'valence_mean': '2.4300000000000002',
#    'valence_sd': '1.47',
#    'arousal_mean': '5.6799999999999997',
#    'arousal_sd': '2.3700000000000001',
#    'dominance_mean': '3.4300000000000002',
#    'dominance_sd': '2.1099999999999999',
#    'word_frequency': '4',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'repeat'},
#   {'description': 'silk',
#    'word_no': '391',
#    'valence_mean': '6.9000000000000004',
#    'valence_sd': '1.27',
#    'arousal_mean': '3.71',
#    'arousal_sd': '2.5099999999999998',
#    'dominance_mean': '4.8099999999999996',
#    'dominance_sd': '1.9299999999999999',
#    'word_frequency': '12',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'once'},
#   {'description': 'kids',
#    'word_no': '835',
#    'valence_mean': '6.9100000000000001',
#    'valence_sd': '1.99',
#    'arousal_mean': '5.2699999999999996',
#    'arousal_sd': '2.3599999999999999',
#    'dominance_mean': '5.0700000000000003',
#    'dominance_sd': '2.0299999999999998',
#    'word_frequency': '32',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'twilight',
#    'word_no': '1022',
#    'valence_mean': '7.2300000000000004',
#    'valence_sd': '1.8',
#    'arousal_mean': '4.7000000000000002',
#    'arousal_sd': '2.4100000000000001',
#    'dominance_mean': '5.5899999999999999',
#    'dominance_sd': '1.8200000000000001',
#    'word_frequency': '4',
#    'valence': 'pos',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'refresh'},
#   {'description': 'leprosy',
#    'word_no': '254',
#    'valence_mean': '2.0899999999999999',
#    'valence_sd': '1.3999999999999999',
#    'arousal_mean': '6.29',
#    'arousal_sd': '2.23',
#    'dominance_mean': '4.0',
#    'dominance_sd': '2.2999999999999998',
#    'word_frequency': '1',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'repeat'},
#   {'description': 'detail',
#    'word_no': '724',
#    'valence_mean': '5.5499999999999998',
#    'valence_sd': '1.5800000000000001',
#    'arousal_mean': '4.0999999999999996',
#    'arousal_sd': '2.2400000000000002',
#    'dominance_mean': '5.21',
#    'dominance_sd': '1.6000000000000001',
#    'word_frequency': '72',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'repeat'},
#   {'description': 'frog',
#    'word_no': '176',
#    'valence_mean': '5.71',
#    'valence_sd': '1.74',
#    'arousal_mean': '4.54',
#    'arousal_sd': '2.0299999999999998',
#    'dominance_mean': '5.3399999999999999',
#    'dominance_sd': '1.96',
#    'word_frequency': '1',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'repeat'},
#   {'description': 'slime',
#    'word_no': '400',
#    'valence_mean': '2.6800000000000002',
#    'valence_sd': '1.6599999999999999',
#    'arousal_mean': '5.3600000000000003',
#    'arousal_sd': '2.6299999999999999',
#    'dominance_mean': '4.1699999999999999',
#    'dominance_sd': '1.8200000000000001',
#    'word_frequency': '1',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'refresh'},
#   {'description': 'activate',
#    'word_no': '4',
#    'valence_mean': '5.46',
#    'valence_sd': '0.97999999999999998',
#    'arousal_mean': '4.8600000000000003',
#    'arousal_sd': '2.5600000000000001',
#    'dominance_mean': '5.4299999999999997',
#    'dominance_sd': '1.8400000000000001',
#    'word_frequency': '2',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'refresh'},
#   {'description': 'infection',
#    'word_no': '228',
#    'valence_mean': '1.6599999999999999',
#    'valence_sd': '1.3400000000000001',
#    'arousal_mean': '5.0300000000000002',
#    'arousal_sd': '2.77',
#    'dominance_mean': '3.6099999999999999',
#    'dominance_sd': '2.6400000000000001',
#    'word_frequency': '8',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'once'},
#   {'description': 'hotel',
#    'word_no': '795',
#    'valence_mean': '6.0',
#    'valence_sd': '1.77',
#    'arousal_mean': '4.7999999999999998',
#    'arousal_sd': '2.5299999999999998',
#    'dominance_mean': '5.1200000000000001',
#    'dominance_sd': '1.8400000000000001',
#    'word_frequency': '126',
#    'valence': 'neu',
#    'pres_num': 1,
#    'probe': 'target',
#    'cond': 'refresh'},
#   {'description': 'immoral',
#    'word_no': '807',
#    'valence_mean': '3.5',
#    'valence_sd': '2.1600000000000001',
#    'arousal_mean': '4.9800000000000004',
#    'arousal_sd': '2.48',
#    'dominance_mean': '4.6600000000000001',
#    'dominance_sd': '2.3300000000000001',
#    'word_frequency': '5',
#    'valence': 'neg',
#    'pres_num': 1,
#    'probe': 'lure',
#    'cond': 'repeat'}]}
